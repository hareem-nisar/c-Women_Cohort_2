# %%
from google.colab import drive
drive.mount('/content/gdrive')

import sys
sys.path.append('/content/gdrive/MyDrive/Colab Notebooks/c-Women Notebooks')

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot

# load image as pixel array
img1 = image.imread('rainbow.jpg')

# summarize shape of the pixel array
print(img1.dtype)
print(img1.shape)

# display the array of pixels as an image
pyplot.imshow(img1)
pyplot.show()
# Out:
# uint8
# (294, 294, 3)

# %%
#Let's load a different rectangular image 

img2 = image.imread('love.jpg')
pyplot.imshow(img2)
print(img2.shape)
print(type(img2))
# Out:
# (374, 666, 3)
# <class 'numpy.ndarray'>

# %%
# what if image was NOT a numpy array by default??
import numpy as np

#then you convert it into one.
arr2 = np.array(img2)
#print(arr2)

# %%
print(type(img2))
print(type(arr2))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# more on image processing libraries
# https://builtin.com/data-science/python-image-processing
